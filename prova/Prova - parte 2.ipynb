# %% [markdown]
# # Pova - parte 2

# %% [markdown]
# ### 1. Importe os módulos necessários

# %%
import pandas as pd

# %% [markdown]
# ###  2. Crie um dataset com base nesse dicionário

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %% [markdown]
# ### 3. Crie um dataframe com nome army.

# %%
army = pd.DataFrame(raw_data)
army
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 5     Dragoons     1st     234        7  1006        37          1        1
# 6     Dragoons     2nd     523        8   987       949          2        0
# 7     Dragoons     2nd      62        3   849        48          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# ...

# %% [markdown]
# ###  4. Coloque a coluna 'origin' como o indice do dataframe

# %%
army.set_index('origin')
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %% [markdown]
# ### 5. Imprima somente a coluna de veteranos

# %%
print(army['veterans'])
# Out:
# 0       1
# 1       5
# 2      62
# 3      26
# 4      73
# 5      37
# 6     949
# 7      48
# 8      48
# 9     435
# 10     63
# 11    345
# Name: veterans, dtype: int64

# %% [markdown]
# ### 6. Imprima as colunas 'veterans' e 'deaths'

# %%
army[['veterans', 'deaths']]
# Out:
#     veterans  deaths
# 0          1     523
# 1          5      52
# 2         62      25
# 3         26     616
# 4         73      43
# 5         37     234
# 6        949     523
# 7         48      62
# 8         48      62
# 9        435      73
# 10        63      37
# 11       345      35

# %% [markdown]
# ###  7. Imprima o nome de todas as colunas

# %%
print(army.columns)
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters', 'origin'],
#       dtype='object')

# %%
army.columns.tolist()

# %% [markdown]
# ### 8. Selecione as colunas 'deaths', 'size' e 'deserters' do Maine e Alaska

# %%
army[(army['origin'] == 'Maine') | (army['origin'] == 'Alaska')][['deaths', 'size', 'deserters']]
# Out:
#    deaths  size  deserters
# 4      43  1592          3
# 6     523   987         24

# %%
# ou

# %%
print('Maine')
print(army[army['origin'] == 'Maine'][['deaths', 'size', 'deserters']])
print()
print('Alaska')
print(army[army['origin'] == 'Alaska'][['deaths', 'size', 'deserters']])
# Out:
# Maine
#    deaths  size  deserters
# 4      43  1592          3
#
# Alaska
#    deaths  size  deserters
# 6     523   987         24

# %% [markdown]
# ### 9. Selecione as linhas 3 a 7 e as colunas 3 a 6

# %%
army.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   regiment   12 non-null     object
#  1   company    12 non-null     object
#  2   deaths     12 non-null     int64
#  3   battles    12 non-null     int64
#  4   size       12 non-null     int64
#  5   veterans   12 non-null     int64
#  6   readiness  12 non-null     int64
#  7   armored    12 non-null     int64
#  8   deserters  12 non-null     int64
#  9   origin     12 non-null     object
# dtypes: int64(7), object(3)
# memory usage: 1.1+ KB

# %%
army.loc[[2, 3, 4, 5, 6],['deaths', 'battles', 'size', 'veterans']]
# Out:
#    deaths  battles  size  veterans
# 2      25        2  1099        62
# 3     616        2  1400        26
# 4      43        4  1592        73
# 5     234        7  1006        37
# 6     523        8   987       949

# %% [markdown]
# ### 10. Selecione todas as linhas após a quarta. Faça isso para todas as colunas.

# %%
army[4:]
# Out:
#     regiment company  deaths  battles  size  veterans  readiness  armored  \
# 4   Dragoons     1st      43        4  1592        73          2        0
# 5   Dragoons     1st     234        7  1006        37          1        1
# 6   Dragoons     2nd     523        8   987       949          2        0
# 7   Dragoons     2nd      62        3   849        48          3        1
# 8     Scouts     1st      62        4   973        48          2        0
# 9     Scouts     1st      73        7  1005       435          1        0
# 10    Scouts     2nd      37        8  1099        63          2        1
# 11    Scouts     2nd      35        9  1523       345          3        1
#
#     deserters      origin
# 4           3       Maine
# 5           4        Iowa
# 6          24      Alaska
# 7          31  Washington
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %% [markdown]
# ### 11. Selecione todas as linhas até a quarta. Faça isso para todas as colunas.

# %%
army[:3]
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 1  Nighthawks     1st      52       42   957         5          2        0
# 2  Nighthawks     2nd      25        2  1099        62          3        1
#
#    deserters      origin
# 0          4     Arizona
# 1         24  California
# 2         31       Texas

# %% [markdown]
# ### 12. Selecione da terceira coluna até a sétima.

# %%
army[['deaths', 'battles', 'size', 'veterans', 'readiness']]
# Out:
#     deaths  battles  size  veterans  readiness
# 0      523        5  1045         1          1
# 1       52       42   957         5          2
# 2       25        2  1099        62          3
# 3      616        2  1400        26          3
# 4       43        4  1592        73          2
# 5      234        7  1006        37          1
# 6      523        8   987       949          2
# 7       62        3   849        48          3
# 8       62        4   973        48          2
# 9       73        7  1005       435          1
# 10      37        8  1099        63          2
# 11      35        9  1523       345          3

# %% [markdown]
# ### 13. Selecione as linhas onde 'deaths' são maiores que 50.

# %%
army[army['deaths'] > 50]
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 1  Nighthawks     1st      52       42   957         5          2        0
# 3  Nighthawks     2nd     616        2  1400        26          3        1
# 5    Dragoons     1st     234        7  1006        37          1        1
# 6    Dragoons     2nd     523        8   987       949          2        0
# 7    Dragoons     2nd      62        3   849        48          3        1
# 8      Scouts     1st      62        4   973        48          2        0
# 9      Scouts     1st      73        7  1005       435          1        0
#
#    deserters      origin
# 0          4     Arizona
# 1         24  California
# 3          2     Florida
# 5          4        Iowa
# 6         24      Alaska
# 7         31  Washington
# 8          2      Oregon
# 9          3     Wyoming

# %% [markdown]
# ### 14. Selecione as linhas onde 'deaths' é maior que 500 ou menor que 50.

# %%
army[(army['deaths'] > 500) | (army['deaths'] < 50)]
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 6     Dragoons     2nd     523        8   987       949          2        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# 11      Scouts     2nd      35        9  1523       345          3        1
#
#     deserters    origin
# 0           4   Arizona
# 2          31     Texas
# 3           2   Florida
# 4           3     Maine
# 6          24    Alaska
# 10          2  Louisana
# 11          3   Georgia

# %% [markdown]
# ### 15. Selecione todos os regimentos que não são "Dragoons".

# %%
army[army['regiment'] != 'Dragoons']
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# 11      Scouts     2nd      35        9  1523       345          3        1
#
#     deserters      origin
# 0           4     Arizona
# 1          24  California
# 2          31       Texas
# 3           2     Florida
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %% [markdown]
# ### 16. Selecione as linhas chamadas de Texas e Arizona

# %%
army[(army['origin'] == 'Texas') | (army['origin'] == 'Arizona')]
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 2  Nighthawks     2nd      25        2  1099        62          3        1
#
#    deserters   origin
# 0          4  Arizona
# 2         31    Texas

# %% [markdown]
# ### 17. Selecione a terceira célula na linha chamada Arizona

# %%
army[army['origin'] == 'Arizona'].values[0][2]
# Out:
# 523

# %% [markdown]
# ### 18. Selecione a terceira célula para baixo na coluna chamada deaths

# %%
army[2:]['deaths']
# Out:
# 2      25
# 3     616
# 4      43
# 5     234
# 6     523
# 7      62
# 8      62
# 9      73
# 10     37
# 11     35
# Name: deaths, dtype: int64
